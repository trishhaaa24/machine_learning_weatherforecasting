# %%
import pandas as pd
weather = pd.read_csv("weather.csv", index_col = "DATE")

# %%
weather
# Out:
#                 STATION                              NAME   ACMH   ACSH  \
# DATE
# 1980-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   40.0   60.0
# 1980-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   50.0   50.0
# 1980-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   10.0   20.0
# 1980-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   70.0   90.0
# 1980-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  100.0  100.0
# ...                 ...                               ...    ...    ...
# 2024-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN    NaN
# 2024-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN    NaN
# 2024-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN    NaN
# 2024-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN    NaN
# 2024-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US    NaN    NaN
#
#              AWND  FMTM    PGTM  PRCP  SNOW  SNWD  ...  WT13  WT14  WT15  \
# DATE                                               ...
# 1980-01-01    NaN   NaN  1036.0  0.00   0.0   0.0  ...   NaN   NaN   NaN
# 1980-01-02    NaN   NaN   954.0  0.00   0.0   0.0  ...   NaN   NaN   NaN
# 1980-01-03    NaN   NaN  1912.0  0.00   0.0   0.0  ...   NaN   NaN   NaN
# 1980-01-04    NaN   NaN  2230.0  0.00   0.0   0.0  ...   NaN   NaN   NaN
# 1980-01-05    NaN   NaN  1418.0  0.09   3.0   2.0  ...   NaN   NaN   NaN
# ...           ...   ...     ...   ...   ...   ...  ...   ...   ...   ...
# 2024-03-11  26.62   NaN     NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN
# 2024-03-12  13.42   NaN     NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN
# 2024-03-13   6.04   NaN     NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN
# 2024-03-14   6.04   NaN  1602.0  0.00   0.0   0.0  ...   NaN   NaN   NaN
# 2024-03-15    NaN   NaN     NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
#
#             WT16  WT17  WT18  WT19  WT21  WT22  WV01
# DATE
# 1980-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1980-01-02   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1980-01-03   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1980-01-04   NaN   NaN   1.0   NaN   NaN   NaN   NaN
# 1980-01-05   NaN   NaN   1.0   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...   ...   ...
# 2024-03-11   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-03-12   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-03-13   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-03-14   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-03-15   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [16146 rows x 45 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.630683
# ACSH       0.630621
# AWND       0.091106
# FMTM       0.372972
# PGTM       0.337545
# PRCP       0.000062
# SNOW       0.000124
# SNWD       0.000186
# TAVG       0.586585
# TMAX       0.000062
# TMIN       0.000062
# TSUN       0.998204
# WDF1       0.630930
# WDF2       0.369937
# WDF5       0.375077
# WDFG       0.682832
# WDFM       0.999938
# WESD       0.629568
# WSF1       0.630744
# WSF2       0.369937
# WSF5       0.375139
# WSFG       0.635390
# WSFM       0.999938
# WT01       0.618419
# WT02       0.941595
# WT03       0.930633
# WT04       0.982720
# WT05       0.977765
# WT06       0.991143
# WT07       0.993311
# WT08       0.862195
# WT09       0.992939
# WT11       0.999133
# WT13       0.864672
# WT14       0.945064
# WT15       0.997399
# WT16       0.686424
# WT17       0.996284
# WT18       0.943701
# WT19       0.999938
# WT21       0.999690
# WT22       0.996965
# WV01       0.999938
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < .05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1980-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1980-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1980-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1980-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1980-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.09   3.0   2.0
# ...                 ...                               ...   ...   ...   ...
# 2024-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN   NaN   NaN
#
#             tmax  tmin
# DATE
# 1980-01-01  42.0  26.0
# 1980-01-02  41.0  31.0
# 1980-01-03  36.0  28.0
# 1980-01-04  30.0  20.0
# 1980-01-05  29.0  25.0
# ...          ...   ...
# 2024-03-11  53.0  35.0
# 2024-03-12  67.0  41.0
# 2024-03-13  57.0  41.0
# 2024-03-14  66.0  41.0
# 2024-03-15   NaN   NaN
#
# [16146 rows x 7 columns]

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.apply(lambda x: (x == 9999).sum())
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax       float64
# tmin       float64
# dtype: object

# %%
weather.index
# Out:
# Index(['1980-01-01', '1980-01-02', '1980-01-03', '1980-01-04', '1980-01-05',
#        '1980-01-06', '1980-01-07', '1980-01-08', '1980-01-09', '1980-01-10',
#        ...
#        '2024-03-06', '2024-03-07', '2024-03-08', '2024-03-09', '2024-03-10',
#        '2024-03-11', '2024-03-12', '2024-03-13', '2024-03-14', '2024-03-15'],
#       dtype='object', name='DATE', length=16146)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024     75
# Name: count, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1980-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1980-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1980-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1980-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1980-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.09   3.0   2.0
# ...                 ...                               ...   ...   ...   ...
# 2024-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1980-01-01  42.0  26.0    41.0
# 1980-01-02  41.0  31.0    36.0
# 1980-01-03  36.0  28.0    30.0
# 1980-01-04  30.0  20.0    29.0
# 1980-01-05  29.0  25.0    28.0
# ...          ...   ...     ...
# 2024-03-11  53.0  35.0    67.0
# 2024-03-12  67.0  41.0    57.0
# 2024-03-13  57.0  41.0    66.0
# 2024-03-14  66.0  41.0    66.0
# 2024-03-15  66.0  41.0     NaN
#
# [16146 rows x 8 columns]

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1980-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1980-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1980-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1980-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1980-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.09   3.0   2.0
# ...                 ...                               ...   ...   ...   ...
# 2024-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1980-01-01  42.0  26.0    41.0
# 1980-01-02  41.0  31.0    36.0
# 1980-01-03  36.0  28.0    30.0
# 1980-01-04  30.0  20.0    29.0
# 1980-01-05  29.0  25.0    28.0
# ...          ...   ...     ...
# 2024-03-11  53.0  35.0    67.0
# 2024-03-12  67.0  41.0    57.0
# 2024-03-13  57.0  41.0    66.0
# 2024-03-14  66.0  41.0    66.0
# 2024-03-15  66.0  41.0    66.0
#
# [16146 rows x 8 columns]

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
def backtest(weather, model, predictors, start=3650, step=90):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.123662344567848

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2007-03-26    78.0   49.789534  28.210466
# 1998-03-26    80.0   53.067943  26.932057
# 1999-01-02    53.0   26.109744  26.890256
# 1990-03-12    85.0   58.149556  26.850444
# 2016-02-14    44.0   17.915955  26.084045
# ...            ...         ...        ...
# 2007-10-25    61.0   61.003469   0.003469
# 2000-09-02    84.0   83.997401   0.002599
# 2020-02-03    53.0   52.997638   0.002362
# 2011-05-22    63.0   63.002185   0.002185
# 1992-01-04    53.0   52.999540   0.000460
#
# [12496 rows x 3 columns]

# %%
pd.Series(rr.coef_, index=predictors)
# Out:
# prcp   -1.069775
# snow   -0.425895
# snwd    0.065048
# tmax    0.456329
# tmin    0.505192
# dtype: float64

# %%
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather
    
rolling_horizons = [3, 14]
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather = weather.iloc[14:,:]
weather = weather.fillna(0)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictions = backtest(weather, rr, predictors)
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 4.7826332532720555

# %%
mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 37.54427420495692

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1990-03-12    85.0   54.679708  30.320292
# 2007-03-26    78.0   50.158958  27.841042
# 1998-03-26    80.0   52.412957  27.587043
# 2003-04-15    86.0   59.679657  26.320343
# 2022-12-23    16.0   41.453376  25.453376
# ...            ...         ...        ...
# 2002-03-28    52.0   51.997178   0.002822
# 1992-12-06    43.0   43.001887   0.001887
# 2017-05-26    73.0   72.999465   0.000535
# 2003-11-05    60.0   59.999587   0.000413
# 2004-04-30    65.0   65.000354   0.000354
#
# [12482 rows x 3 columns]

# %%
weather.loc["2021-07-07": "2021-07-07"]
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 2021-07-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   0.0   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  ...  \
# DATE                                                                ...
# 2021-07-07  89.0  71.0    81.0       85.666667            0.038911  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 2021-07-07        66.571429             0.066524         0.172143
#
#             rolling_14_prcp_pct  month_avg_tmax  day_avg_tmax  month_avg_tmin  \
# DATE
# 2021-07-07                 -1.0       83.676839     83.642857       69.125196
#
#             day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 2021-07-07     68.690476        0.131839      0.101905
#
# [1 rows x 26 columns]

# %%
(predictions["diff"].round().value_counts().sort_index() / predictions.shape[0]).plot()
# Out:
# <Axes: xlabel='diff'>

# %%
 predictions
# Out:
#             actual  prediction       diff
# DATE
# 1990-01-12    34.0   41.804645   7.804645
# 1990-01-13    37.0   36.253018   0.746982
# 1990-01-14    41.0   38.158732   2.841268
# 1990-01-15    51.0   43.109104   7.890896
# 1990-01-16    51.0   46.227086   4.772914
# ...            ...         ...        ...
# 2024-03-11    67.0   49.994428  17.005572
# 2024-03-12    57.0   58.268173   1.268173
# 2024-03-13    66.0   55.113466  10.886534
# 2024-03-14    66.0   57.931415   8.068585
# 2024-03-15    66.0   58.174441   7.825559
#
# [12482 rows x 3 columns]

# %%
predictions["2021-07-07": "2021-07-07"]
# Out:
#             actual  prediction      diff
# DATE
# 2021-07-07    81.0   86.238601  5.238601
